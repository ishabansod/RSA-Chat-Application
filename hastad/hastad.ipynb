# %%
def egcd(a, b):
    x0, x1, y0, y1 = 0, 1, 1, 0
    while a != 0:
        #(q, a), b = divmod(b, a), a
        q, a, b = b // a, b % a, a
        y0, y1 = y1, y0 - q * y1
        x0, x1 = x1, x0 - q * x1
    return b, x0, y0

def gcd(x, y):
    res = 0
    if x > y:
        small = y
    else:
        small = x
    for i in range(1, small + 1):
        if (x % i == 0) and (y % i == 0):
            res = i

    return res

import secrets
import string


def genrandomstring(length):
    password_characters = string.ascii_letters + string.digits + string.punctuation + string.whitespace
    password = ''.join(secrets.choice(password_characters) for i in range(length))
    return password

def modinv(a, m):
    g, x, y = egcd(a, m)
    if g != 1:
        raise Exception('modular inverse does not exist')
    else:
        return x % m
    
def modpow(a, n, p):
    res = 1
    a = a % p

    while n > 0:
        if n % 2:
            res = (res * a) % p
            n = n - 1
        else:
            a = (a ** 2) % p
            n = n // 2

    return res % p


def getrandom(size):
    prime = secrets.randbits(size)
    return prime


def randomexponent(phi):
    e = 0
    good = False
    while not good:
        e = getrandom(16)
        e = e % 19193
        e += 46341
        e += 1 - e % 2
        if e > 65535:
            e = 46341
        while gcd(e, phi) != 1:
            e = e + 2
        if e <= phi:
            good = True
    return e

# %%
def fermatprimalitytest(n, k):
    if n == 1 or n == 4:
        return False
    if n == 2 or n == 3:
        return True

    if n % 2 == 0:
        return False

    for i in range(k):
        a = secrets.randbelow(n - 1)
        if a < 1:
            a = 1

        #   if gcd(n, a) != 1:
            #   return False

        if modpow(a, n - 1, n) != 1:
            return False

    return True

def millerwitness(d, n):
    if n < 4:
        return False
    a = secrets.randbelow(n - 2)
    if a < 2 and n > 3:
        a = a + 2
    if a < 1:
        a = 1

    x = modpow(a, d, n)

    if x == 1 or x == n - 1:
        return True

    while d != n - 1:
        x = (x * x) % n
        d *= 2

        if x == 1:
            return False
        if x == n - 1:
            return True
    return False



def millerrabinprimalitytest(n, k):
    # Corner cases
    if n <= 1 or n == 4:
        return False
    if n <= 3:
        return True

    # Find r such that n = 2^d * r + 1 for some r >= 1
    d = n - 1
    while d % 2 == 0:
        d //= 2

    for i in range(k):
        if not millerwitness(d, n):
            return False

    return True



def randomprime():
    # random number between 46341 and 65535
    prime = getrandom(16)
    prime = prime % 19193
    prime += 46341
    prime += 1 - prime % 2
    if prime > 65521:
        prime = 65521
    while not fermatprimalitytest(prime, 40) or not millerrabinprimalitytest(prime, 40):
        prime = prime + 2
    return prime


def crt(items):
    # Determine N, the product of all n_i
    N = 1
    for a, n in items:
        N *= n

    # Find the solution (mod N)
    result = 0
    for a, n in items:
        m = N // n
        d, r, s = egcd(n, m)
        if d != 1:
            raise Exception("Input not pairwise co-prime")
        result += a * s * m

    return result % N

# %%
def rsaencrypt(plaintxt, pubkey, isint):
    if isint:
        cipher = [modpow(char, pubkey.exp, pubkey.mod) for char in plaintxt]
    else:
        cipher = [modpow(ord(char), pubkey.exp, pubkey.mod) for char in plaintxt]

    return cipher

# %%
class PublicKey:
    def __init__(self, exp, mod):
        self.exp = exp
        self.mod = mod
        
class PrivateKey:
    def __init__(self, modinv, mod):
        self.modinv = modinv
        self.mod = mod

# %%
def hastadbroadcast():
    plaintxt = genrandomstring(128)
    good = False
    mod1, mod2, mod3 = 0, 0, 0
    while good is not True:
        p1 = randomprime()
        p2 = randomprime()
        mod1 = p1 * p2
        p3 = randomprime()
        p4 = randomprime()
        mod2 = p3 * p4
        p5 = randomprime()
        p6 = randomprime()
        mod3 = p5 * p6
        print("random prime 1 numbers are", p1, "and", p2, '\n')
        print("random prime 2 numbers are", p3, "and", p4, '\n')
        print("random prime 3 numbers are", p5, "and", p6, '\n')
        print("modulo 1 is", mod1, '\n')
        print("modulo 2 is", mod2, '\n')
        print("modulo 3 is", mod3, '\n')
        good = True
        if egcd(mod1, mod2)[0] != 1:
            print("mod1 & mod2 aren't coprime")
            good = False
        if egcd(mod1, mod3)[0] != 1:
            print("mod1 & mod3 aren't coprime")
            good = False
        if egcd(mod2, mod3)[0] != 1:
            print("mod2 & mod3 aren't coprime")
            good = False
    e = 3
    print("exponent is", mod1, '\n')
    c1 = rsaencrypt(plaintxt, PublicKey(e, mod1), False)
    c2 = rsaencrypt(plaintxt, PublicKey(e, mod2), False)
    c3 = rsaencrypt(plaintxt, PublicKey(e, mod3), False)
    print("Plain text START")
    print(plaintxt)
    print("Plain text END\n")
    print("Cipher text 1 = ", c1, '\n')
    print("Cipher text 2 = ", c2, '\n')
    print("Cipher text 3 = ", c3, '\n')
    result = ""
    for i in range(0, len(c1)):
        crtres = crt([(c1[i], mod1), (c2[i], mod2), (c3[i], mod3)])
        print("[ATTACK] crt result =", crtres)
        crtroot = round(crtres ** (1 / e))
        print("[ATTACK] racine cubique =", crtroot)
        result = result + chr(round(crtroot))
    print("Deciphered text START")
    print(result)
    print("Deciphered text END\n")

# %%
hastadbroadcast()
# Out:
# random prime 1 numbers are 58657 and 58147
#
# random prime 2 numbers are 54601 and 58511
#
# random prime 3 numbers are 51613 and 60679
#
# modulo 1 is 3410728579
#
# modulo 2 is 3194759111
#
# modulo 3 is 3131825227
#
# exponent is 3410728579
#
# Plain text START
#
# 5P6/76U+Ck1F7!`
# Plain text END
#
# Cipher text 1 =  [1000, 1225043, 1771561, 1331000, 1000000, 39304, 185193, 1295029, 50653, 59319, 941192, 1728, 1860867, 103823, 830584, 148877, 175616, 658503, 681472, 91125, 474552, 1092727, 74088, 1728000, 1092727, 1728, 1520875, 474552, 35937, 46656, 729000, 59319, 1771561, 2000376, 857375, 132651, 438976, 704969, 262144, 117649, 97336, 2197, 493039, 148877, 148877, 1295029, 438976, 1259712, 421875, 941192, 405224, 140608, 753571, 456533, 551368, 328509, 103823, 1061208, 185193, 405224, 39304, 421875, 54872, 91125, 658503, 91125, 830584, 857375, 531441, 571787, 140608, 1157625, 314432, 658503, 658503, 46656, 54872, 2000376, 1728, 103823, 373248, 1685159, 1124864, 373248, 68921, 110592, 1295029, 1728, 54872, 493039, 1953125, 1953125, 804357, 658503, 512000, 778688, 148877, 592704, 238328, 140608, 778688, 1061208, 941192, 753571, 238328, 571787, 1061208, 314432, 35937, 59319, 1953125, 1225043, 2197, 148877, 512000, 157464, 103823, 166375, 157464, 614125, 79507, 300763, 1225043, 117649, 343000, 166375, 35937, 884736]
#
# Cipher text 2 =  [1000, 1225043, 1771561, 1331000, 1000000, 39304, 185193, 1295029, 50653, 59319, 941192, 1728, 1860867, 103823, 830584, 148877, 175616, 658503, 681472, 91125, 474552, 1092727, 74088, 1728000, 1092727, 1728, 1520875, 474552, 35937, 46656, 729000, 59319, 1771561, 2000376, 857375, 132651, 438976, 704969, 262144, 117649, 97336, 2197, 493039, 148877, 148877, 1295029, 438976, 1259712, 421875, 941192, 405224, 140608, 753571, 456533, 551368, 328509, 103823, 1061208, 185193, 405224, 39304, 421875, 54872, 91125, 658503, 91125, 830584, 857375, 531441, 571787, 140608, 1157625, 314432, 658503, 658503, 46656, 54872, 2000376, 1728, 103823, 373248, 1685159, 1124864, 373248, 68921, 110592, 1295029, 1728, 54872, 493039, 1953125, 1953125, 804357, 658503, 512000, 778688, 148877, 592704, 238328, 140608, 778688, 1061208, 941192, 753571, 238328, 571787, 1061208, 314432, 35937, 59319, 1953125, 1225043, 2197, 148877, 512000, 157464, 103823, 166375, 157464, 614125, 79507, 300763, 1225043, 117649, 343000, 166375, 35937, 884736]
#
# Cipher text 3 =  [1000, 1225043, 1771561, 1331000, 1000000, 39304, 185193, 1295029, 50653, 59319, 941192, 1728, 1860867, 103823, 830584, 148877, 175616, 658503, 681472, 91125, 474552, 1092727, 74088, 1728000, 1092727, 1728, 1520875, 474552, 35937, 46656, 729000, 59319, 1771561, 2000376, 857375, 132651, 438976, 704969, 262144, 117649, 97336, 2197, 493039, 148877, 148877, 1295029, 438976, 1259712, 421875, 941192, 405224, 140608, 753571, 456533, 551368, 328509, 103823, 1061208, 185193, 405224, 39304, 421875, 54872, 91125, 658503, 91125, 830584, 857375, 531441, 571787, 140608, 1157625, 314432, 658503, 658503, 46656, 54872, 2000376, 1728, 103823, 373248, 1685159, 1124864, 373248, 68921, 110592, 1295029, 1728, 54872, 493039, 1953125, 1953125, 804357, 658503, 512000, 778688, 148877, 592704, 238328, 140608, 778688, 1061208, 941192, 753571, 238328, 571787, 1061208, 314432, 35937, 59319, 1953125, 1225043, 2197, 148877, 512000, 157464, 103823, 166375, 157464, 614125, 79507, 300763, 1225043, 117649, 343000, 166375, 35937, 884736]
#
# [ATTACK] crt result = 1000
# [ATTACK] racine cubique = 10
# [ATTACK] crt result = 1225043
# [ATTACK] racine cubique = 107
# [ATTACK] crt result = 1771561
# [ATTACK] racine cubique = 121
# [ATTACK] crt result = 1331000
# [ATTACK] racine cubique = 110
# [ATTACK] crt result = 1000000
# [ATTACK] racine cubique = 100
# [ATTACK] crt result = 39304
# [ATTACK] racine cubique = 34
# [ATTACK] crt result = 185193
# [ATTACK] racine cubique = 57
# [ATTACK] crt result = 1295029
# [ATTACK] racine cubique = 109
# [ATTACK] crt result = 50653
# [ATTACK] racine cubique = 37
# [ATTACK] crt result = 59319
# [ATTACK] racine cubique = 39
# [ATTACK] crt result = 941192
# [ATTACK] racine cubique = 98
# [ATTACK] crt result = 1728
# [ATTACK] racine cubique = 12
# [ATTACK] crt result = 1860867
# [ATTACK] racine cubique = 123
# [ATTACK] crt result = 103823
# [ATTACK] racine cubique = 47
# [ATTACK] crt result = 830584
# [ATTACK] racine cubique = 94
# [ATTACK] crt result = 148877
# [ATTACK] racine cubique = 53
# [ATTACK] crt result = 175616
# [ATTACK] racine cubique = 56
# [ATTACK] crt result = 658503
# [ATTACK] racine cubique = 87
# [ATTACK] crt result = 681472
# [ATTACK] racine cubique = 88
# [ATTACK] crt result = 91125
# [ATTACK] racine cubique = 45
# [ATTACK] crt result = 474552
# [ATTACK] racine cubique = 78
# [ATTACK] crt result = 1092727
# [ATTACK] racine cubique = 103
# [ATTACK] crt result = 74088
# [ATTACK] racine cubique = 42
# [ATTACK] crt result = 1728000
# [ATTACK] racine cubique = 120
# [ATTACK] crt result = 1092727
# [ATTACK] racine cubique = 103
# [ATTACK] crt result = 1728
# [ATTACK] racine cubique = 12
# [ATTACK] crt result = 1520875
# [ATTACK] racine cubique = 115
# [ATTACK] crt result = 474552
# [ATTACK] racine cubique = 78
# [ATTACK] crt result = 35937
# [ATTACK] racine cubique = 33
# [ATTACK] crt result = 46656
# [ATTACK] racine cubique = 36
# [ATTACK] crt result = 729000
# [ATTACK] racine cubique = 90
# [ATTACK] crt result = 59319
# [ATTACK] racine cubique = 39
# [ATTACK] crt result = 1771561
# [ATTACK] racine cubique = 121
# [ATTACK] crt result = 2000376
# [ATTACK] racine cubique = 126
# [ATTACK] crt result = 857375
# [ATTACK] racine cubique = 95
# [ATTACK] crt result = 132651
# [ATTACK] racine cubique = 51
# [ATTACK] crt result = 438976
# [ATTACK] racine cubique = 76
# [ATTACK] crt result = 704969
# [ATTACK] racine cubique = 89
# [ATTACK] crt result = 262144
# [ATTACK] racine cubique = 64
# [ATTACK] crt result = 117649
# [ATTACK] racine cubique = 49
# [ATTACK] crt result = 97336
# [ATTACK] racine cubique = 46
# [ATTACK] crt result = 2197
# [ATTACK] racine cubique = 13
# [ATTACK] crt result = 493039
# [ATTACK] racine cubique = 79
# [ATTACK] crt result = 148877
# [ATTACK] racine cubique = 53
# [ATTACK] crt result = 148877
# [ATTACK] racine cubique = 53
# [ATTACK] crt result = 1295029
# [ATTACK] racine cubique = 109
# [ATTACK] crt result = 438976
# [ATTACK] racine cubique = 76
# [ATTACK] crt result = 1259712
# [ATTACK] racine cubique = 108
# [ATTACK] crt result = 421875
# [ATTACK] racine cubique = 75
# [ATTACK] crt result = 941192
# [ATTACK] racine cubique = 98
# [ATTACK] crt result = 405224
# [ATTACK] racine cubique = 74
# [ATTACK] crt result = 140608
# [ATTACK] racine cubique = 52
# [ATTACK] crt result = 753571
# [ATTACK] racine cubique = 91
# [ATTACK] crt result = 456533
# [ATTACK] racine cubique = 77
# [ATTACK] crt result = 551368
# [ATTACK] racine cubique = 82
# [ATTACK] crt result = 328509
# [ATTACK] racine cubique = 69
# [ATTACK] crt result = 103823
# [ATTACK] racine cubique = 47
# [ATTACK] crt result = 1061208
# [ATTACK] racine cubique = 102
# [ATTACK] crt result = 185193
# [ATTACK] racine cubique = 57
# [ATTACK] crt result = 405224
# [ATTACK] racine cubique = 74
# [ATTACK] crt result = 39304
# [ATTACK] racine cubique = 34
# [ATTACK] crt result = 421875
# [ATTACK] racine cubique = 75
# [ATTACK] crt result = 54872
# [ATTACK] racine cubique = 38
# [ATTACK] crt result = 91125
# [ATTACK] racine cubique = 45
# [ATTACK] crt result = 658503
# [ATTACK] racine cubique = 87
# [ATTACK] crt result = 91125
# [ATTACK] racine cubique = 45
# [ATTACK] crt result = 830584
# [ATTACK] racine cubique = 94
# [ATTACK] crt result = 857375
# [ATTACK] racine cubique = 95
# [ATTACK] crt result = 531441
# [ATTACK] racine cubique = 81
# [ATTACK] crt result = 571787
# [ATTACK] racine cubique = 83
# [ATTACK] crt result = 140608
# [ATTACK] racine cubique = 52
# [ATTACK] crt result = 1157625
# [ATTACK] racine cubique = 105
# [ATTACK] crt result = 314432
# [ATTACK] racine cubique = 68
# [ATTACK] crt result = 658503
# [ATTACK] racine cubique = 87
# [ATTACK] crt result = 658503
# [ATTACK] racine cubique = 87
# [ATTACK] crt result = 46656
# [ATTACK] racine cubique = 36
# [ATTACK] crt result = 54872
# [ATTACK] racine cubique = 38
# [ATTACK] crt result = 2000376
# [ATTACK] racine cubique = 126
# [ATTACK] crt result = 1728
# [ATTACK] racine cubique = 12
# [ATTACK] crt result = 103823
# [ATTACK] racine cubique = 47
# [ATTACK] crt result = 373248
# [ATTACK] racine cubique = 72
# [ATTACK] crt result = 1685159
# [ATTACK] racine cubique = 119
# [ATTACK] crt result = 1124864
# [ATTACK] racine cubique = 104
# [ATTACK] crt result = 373248
# [ATTACK] racine cubique = 72
# [ATTACK] crt result = 68921
# [ATTACK] racine cubique = 41
# [ATTACK] crt result = 110592
# [ATTACK] racine cubique = 48
# [ATTACK] crt result = 1295029
# [ATTACK] racine cubique = 109
# [ATTACK] crt result = 1728
# [ATTACK] racine cubique = 12
# [ATTACK] crt result = 54872
# [ATTACK] racine cubique = 38
# [ATTACK] crt result = 493039
# [ATTACK] racine cubique = 79
# [ATTACK] crt result = 1953125
# [ATTACK] racine cubique = 125
# [ATTACK] crt result = 1953125
# [ATTACK] racine cubique = 125
# [ATTACK] crt result = 804357
# [ATTACK] racine cubique = 93
# [ATTACK] crt result = 658503
# [ATTACK] racine cubique = 87
# [ATTACK] crt result = 512000
# [ATTACK] racine cubique = 80
# [ATTACK] crt result = 778688
# [ATTACK] racine cubique = 92
# [ATTACK] crt result = 148877
# [ATTACK] racine cubique = 53
# [ATTACK] crt result = 592704
# [ATTACK] racine cubique = 84
# [ATTACK] crt result = 238328
# [ATTACK] racine cubique = 62
# [ATTACK] crt result = 140608
# [ATTACK] racine cubique = 52
# [ATTACK] crt result = 778688
# [ATTACK] racine cubique = 92
# [ATTACK] crt result = 1061208
# [ATTACK] racine cubique = 102
# [ATTACK] crt result = 941192
# [ATTACK] racine cubique = 98
# [ATTACK] crt result = 753571
# [ATTACK] racine cubique = 91
# [ATTACK] crt result = 238328
# [ATTACK] racine cubique = 62
# [ATTACK] crt result = 571787
# [ATTACK] racine cubique = 83
# [ATTACK] crt result = 1061208
# [ATTACK] racine cubique = 102
# [ATTACK] crt result = 314432
# [ATTACK] racine cubique = 68
# [ATTACK] crt result = 35937
# [ATTACK] racine cubique = 33
# [ATTACK] crt result = 59319
# [ATTACK] racine cubique = 39
# [ATTACK] crt result = 1953125
# [ATTACK] racine cubique = 125
# [ATTACK] crt result = 1225043
# [ATTACK] racine cubique = 107
# [ATTACK] crt result = 2197
# [ATTACK] racine cubique = 13
# [ATTACK] crt result = 148877
# [ATTACK] racine cubique = 53
# [ATTACK] crt result = 512000
# [ATTACK] racine cubique = 80
# [ATTACK] crt result = 157464
# [ATTACK] racine cubique = 54
# [ATTACK] crt result = 103823
# [ATTACK] racine cubique = 47
# [ATTACK] crt result = 166375
# [ATTACK] racine cubique = 55
# [ATTACK] crt result = 157464
# [ATTACK] racine cubique = 54
# [ATTACK] crt result = 614125
# [ATTACK] racine cubique = 85
# [ATTACK] crt result = 79507
# [ATTACK] racine cubique = 43
# [ATTACK] crt result = 300763
# [ATTACK] racine cubique = 67
# [ATTACK] crt result = 1225043
# [ATTACK] racine cubique = 107
# [ATTACK] crt result = 117649
# [ATTACK] racine cubique = 49
# [ATTACK] crt result = 343000
# [ATTACK] racine cubique = 70
# [ATTACK] crt result = 166375
# [ATTACK] racine cubique = 55
# [ATTACK] crt result = 35937
# [ATTACK] racine cubique = 33
# [ATTACK] crt result = 884736
# [ATTACK] racine cubique = 96
# Deciphered text START
#
# 5P6/76U+Ck1F7!`
# Deciphered text END
